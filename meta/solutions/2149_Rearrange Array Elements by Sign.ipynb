# %% [markdown]
# # 2149. Rearrange Array Elements by Sign

# %% [markdown]
# You are given a 0-indexed integer array nums of even length consisting of an equal number of positive and negative integers.You should return the array of nums such that the the array follows the given conditions:Every consecutive pair of integers have opposite signs.For all integers with the same sign, the order in which they were present in nums is preserved.The rearranged array begins with a positive integer.Return the modified array after rearranging the elements to satisfy the aforementioned conditions. **Example 1:**Input: nums = [3,1,-2,-5,2,-4]Output: [3,-2,1,-5,2,-4]Explanation:The positive integers in nums are [3,1,2]. The negative integers are [-2,-5,-4].The only possible way to rearrange them such that they satisfy all conditions is [3,-2,1,-5,2,-4].Other ways such as [1,-2,2,-5,3,-4], [3,1,2,-2,-5,-4], [-2,3,-5,1,-4,2] are incorrect because they do not satisfy one or more conditions.  **Example 2:**Input: nums = [-1,1]Output: [1,-1]Explanation:1 is the only positive integer and -1 the only negative integer in nums.So nums is rearranged to [1,-1]. **Constraints:**2 <= nums.length <= 2 * 105nums.length is even1 <= |nums[i]| <= 105nums consists of equal number of positive and negative integers. It is not required to do the modifications in-place.

# %% [markdown]
# ## Solution Explanation
# To solve this problem, we need to rearrange the array so that:1. Every consecutive pair of integers have opposite signs2. The original order of positive and negative integers is preserved3. The array starts with a positive integerSince we're told the array has an equal number of positive and negative integers, we can create a pattern of alternating positive and negative integers. The approach is:1. Separate the positive and negative integers into two separate arrays while preserving their original order2. Create a new result array by alternating between positive and negative integers3. Start with a positive integer (as required)This approach works because:* We maintain the original order of positive integers and negative integers separately* By alternating between them, we ensure every consecutive pair has opposite signs* By starting with a positive integer, we satisfy the third condition

# %%
def rearrangeArray(nums):    positives = []    negatives = []        # Separate positive and negative numbers    for num in nums:        if num > 0:            positives.append(num)        else:            negatives.append(num)        result = []    # Interleave positive and negative numbers    for i in range(len(positives)):        result.append(positives[i])        result.append(negatives[i])        return result

# %% [markdown]
# ## Time and Space Complexity
# * *Time Complexity**: O(n), where n is the length of the input array. We iterate through the array once to separate positive and negative numbers, and then iterate through half the length of the array to create the result.* *Space Complexity**: O(n), where n is the length of the input array. We create two separate arrays for positive and negative numbers, each containing n/2 elements. We also create a result array of length n.

# %% [markdown]
# ## Test Cases

# %%
def test_rearrangeArray():    # Test case 1: Example from the problem    nums1 = [3, 1, -2, -5, 2, -4]    result1 = rearrangeArray(nums1)    expected1 = [3, -2, 1, -5, 2, -4]    assert result1 == expected1, f"Expected {expected1}, but got {result1}"        # Test case 2: Minimal example    nums2 = [-1, 1]    result2 = rearrangeArray(nums2)    expected2 = [1, -1]    assert result2 == expected2, f"Expected {expected2}, but got {result2}"        # Test case 3: Already alternating but starting with negative    nums3 = [-1, 2, -3, 4]    result3 = rearrangeArray(nums3)    expected3 = [2, -1, 4, -3]    assert result3 == expected3, f"Expected {expected3}, but got {result3}"        # Test case 4: All positives first, then all negatives    nums4 = [1, 2, 3, -1, -2, -3]    result4 = rearrangeArray(nums4)    expected4 = [1, -1, 2, -2, 3, -3]    assert result4 == expected4, f"Expected {expected4}, but got {result4}"        # Test case 5: All negatives first, then all positives    nums5 = [-1, -2, -3, 1, 2, 3]    result5 = rearrangeArray(nums5)    expected5 = [1, -1, 2, -2, 3, -3]    assert result5 == expected5, f"Expected {expected5}, but got {result5}"        print("All test cases passed!")# Run the teststest_rearrangeArray()
