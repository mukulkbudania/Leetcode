# %% [markdown]
# # 1757. Recyclable and Low Fat Products

# %% [markdown]
# SQL SchemaPandas SchemaTable: Products+-------------+---------+| Column Name | Type    |+-------------+---------+| product_id  | int     || low_fats    | enum    || recyclable  | enum    |+-------------+---------+product_id is the primary key (column with unique values) for this table.low_fats is an ENUM (category) of type ('Y', 'N') where 'Y' means this product is low fat and 'N' means it is not.recyclable is an ENUM (category) of types ('Y', 'N') where 'Y' means this product is recyclable and 'N' means it is not. Write a solution to find the ids of products that are both low fat and recyclable.Return the result table in any order.The result format is in the following example. **Example 1:**Input: Products table:+-------------+----------+------------+| product_id  | low_fats | recyclable |+-------------+----------+------------+| 0           | Y        | N          || 1           | Y        | Y          || 2           | N        | Y          || 3           | Y        | Y          || 4           | N        | N          |+-------------+----------+------------+Output: +-------------+| product_id  |+-------------+| 1           || 3           |+-------------+Explanation: Only products 1 and 3 are both low fat and recyclable.

# %% [markdown]
# ## Solution Explanation
# This problem asks us to find product IDs that satisfy two conditions: they must be both low fat (`low_fats = 'Y'`) and recyclable (`recyclable = 'Y'`).The approach is straightforward:1. We need to filter the Products table to find rows where both `low_fats` and `recyclable` columns have the value 'Y'.2. Then we select only the `product_id` column from the filtered results.This can be done with a simple SQL query using the WHERE clause with AND operator to combine both conditions.

# %%
import pandas as pddef find_products(products: pd.DataFrame) -> pd.DataFrame:    """    Find products that are both low fat and recyclable.        Args:        products: DataFrame containing product information            Returns:        DataFrame with product_id of products that are both low fat and recyclable    """    # Filter products that are both low fat and recyclable    result = products[(products['low_fats'] == 'Y') & (products['recyclable'] == 'Y')]        # Select only the product_id column    return result[['product_id']]

# %% [markdown]
# ## Time and Space Complexity
# * *Time Complexity**: O(n), where n is the number of rows in the products DataFrame. We need to scan through each row once to check if it meets both conditions.* *Space Complexity**: O(m), where m is the number of products that satisfy both conditions. In the worst case, if all products are both low fat and recyclable, m would equal n, making the space complexity O(n).

# %% [markdown]
# ## Test Cases

# %%
# Test Case 1: Example from the problem statementdef test_example_case():    data = {        'product_id': [0, 1, 2, 3, 4],        'low_fats': ['Y', 'Y', 'N', 'Y', 'N'],        'recyclable': ['N', 'Y', 'Y', 'Y', 'N']    }    products_df = pd.DataFrame(data)    result = find_products(products_df)        # Expected: products 1 and 3 are both low fat and recyclable    expected = pd.DataFrame({'product_id': [1, 3]})    pd.testing.assert_frame_equal(result.reset_index(drop=True), expected.reset_index(drop=True))    print("Test Case 1 passed!")# Test Case 2: Empty DataFramedef test_empty_dataframe():    products_df = pd.DataFrame(columns=['product_id', 'low_fats', 'recyclable'])    result = find_products(products_df)        # Expected: empty DataFrame with product_id column    expected = pd.DataFrame(columns=['product_id'])    pd.testing.assert_frame_equal(result, expected)    print("Test Case 2 passed!")# Test Case 3: No products meet both conditionsdef test_no_matching_products():    data = {        'product_id': [0, 1, 2],        'low_fats': ['Y', 'N', 'N'],        'recyclable': ['N', 'Y', 'N']    }    products_df = pd.DataFrame(data)    result = find_products(products_df)        # Expected: empty DataFrame with product_id column    expected = pd.DataFrame({'product_id': []})    pd.testing.assert_frame_equal(result, expected)    print("Test Case 3 passed!")# Test Case 4: All products meet both conditionsdef test_all_matching_products():    data = {        'product_id': [10, 20, 30],        'low_fats': ['Y', 'Y', 'Y'],        'recyclable': ['Y', 'Y', 'Y']    }    products_df = pd.DataFrame(data)    result = find_products(products_df)        # Expected: all products are returned    expected = pd.DataFrame({'product_id': [10, 20, 30]})    pd.testing.assert_frame_equal(result.reset_index(drop=True), expected.reset_index(drop=True))    print("Test Case 4 passed!")# Run the teststest_example_case()test_empty_dataframe()test_no_matching_products()test_all_matching_products()
