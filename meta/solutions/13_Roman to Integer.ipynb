# %% [markdown]
# # 13. Roman to Integer

# %% [markdown]
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.Symbol       ValueI             1V             5X             10L             50C             100D             500M             1000For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:I can be placed before V (5) and X (10) to make 4 and 9. X can be placed before L (50) and C (100) to make 40 and 90. C can be placed before D (500) and M (1000) to make 400 and 900.Given a roman numeral, convert it to an integer. **Example 1:**Input: s = "III"Output: 3Explanation: III = 3.**Example 2:**Input: s = "LVIII"Output: 58Explanation: L = 50, V= 5, III = 3.**Example 3:**Input: s = "MCMXCIV"Output: 1994Explanation: M = 1000, CM = 900, XC = 90 and IV = 4. **Constraints:**1 <= s.length <= 15s contains only the characters ('I', 'V', 'X', 'L', 'C', 'D', 'M').It is guaranteed that s is a valid roman numeral in the range [1, 3999].

# %% [markdown]
# ## Solution Explanation
# To convert a Roman numeral to an integer, we need to understand the rules of Roman numerals:1. Generally, Roman numerals are written in descending order of value from left to right.2. When a smaller value appears before a larger value, it represents subtraction (e.g., IV = 4).3. When a smaller value appears after a larger value, it represents addition (e.g., VI = 6).The approach is to iterate through the string from left to right:1. Map each Roman numeral character to its corresponding integer value.2. Compare the current numeral with the next one.3. If the current value is less than the next value, subtract the current value.4. Otherwise, add the current value.5. Always add the last numeral's value.This handles the special subtraction cases (IV, IX, XL, XC, CD, CM) while correctly processing standard cases.

# %%
def romanToInt(s: str) -> int:    # Map Roman numerals to their integer values    roman_values = {        'I': 1,        'V': 5,        'X': 10,        'L': 50,        'C': 100,        'D': 500,        'M': 1000    }        result = 0    prev_value = 0        # Iterate through the string from right to left    for char in reversed(s):        current_value = roman_values[char]                # If current value is greater than or equal to previous value, add it        # Otherwise, subtract it (handles cases like IV, IX, etc.)        if current_value >= prev_value:            result += current_value        else:            result -= current_value                    prev_value = current_value            return result

# %% [markdown]
# ## Time and Space Complexity
# * *Time Complexity**: O(n), where n is the length of the input string. We iterate through each character of the string exactly once.* *Space Complexity**: O(1), as we use a fixed-size dictionary to store the Roman numeral mappings. The space used does not depend on the input size. We only use a constant amount of extra space for variables like `result` and `prev_value`.

# %% [markdown]
# ## Test Cases

# %%
def test_roman_to_int():    # Test case 1: Basic cases    assert romanToInt("III") == 3    assert romanToInt("IV") == 4    assert romanToInt("IX") == 9    assert romanToInt("LVIII") == 58        # Test case 2: Complex case with multiple subtractions    assert romanToInt("MCMXCIV") == 1994        # Test case 3: Edge cases    assert romanToInt("I") == 1  # Single character    assert romanToInt("MMMCMXCIX") == 3999  # Largest valid Roman numeral in constraints        # Test case 4: Cases with repeated numerals    assert romanToInt("XXII") == 22    assert romanToInt("MDCLXVI") == 1666        print("All test cases passed!")# Run the teststest_roman_to_int()
