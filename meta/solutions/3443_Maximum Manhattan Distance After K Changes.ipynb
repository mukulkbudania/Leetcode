# %% [markdown]
# # 3443. Maximum Manhattan Distance After K Changes

# %% [markdown]
# You are given a string s consisting of the characters 'N', 'S', 'E', and 'W', where s[i] indicates movements in an infinite grid:'N' : Move north by 1 unit.'S' : Move south by 1 unit.'E' : Move east by 1 unit.'W' : Move west by 1 unit.Initially, you are at the origin (0, 0). You can change at most k characters to any of the four directions.Find the maximum Manhattan distance from the origin that can be achieved at any time while performing the movements in order.The Manhattan Distance between two cells (xi, yi) and (xj, yj) is |xi - xj| + |yi - yj|. **Example 1:**Input: s = "NWSE", k = 1Output: 3Explanation:Change s[2] from 'S' to 'N'. The string s becomes "NWNE".Movement	Position (x, y)	Manhattan Distance	Maximums[0] == 'N'	(0, 1)	0 + 1 = 1	1s[1] == 'W'	(-1, 1)	1 + 1 = 2	2s[2] == 'N'	(-1, 2)	1 + 2 = 3	3s[3] == 'E'	(0, 2)	0 + 2 = 2	3The maximum Manhattan distance from the origin that can be achieved is 3. Hence, 3 is the output.**Example 2:**Input: s = "NSWWEW", k = 3Output: 6Explanation:Change s[1] from 'S' to 'N', and s[4] from 'E' to 'W'. The string s becomes "NNWWWW".The maximum Manhattan distance from the origin that can be achieved is 6. Hence, 6 is the output. **Constraints:**1 <= s.length <= 1050 <= k <= s.lengths consists of only 'N', 'S', 'E', and 'W'.

# %% [markdown]
# ## Solution Explanation
# To solve this problem, we need to find the maximum Manhattan distance from the origin after changing at most k characters in the string.The key insight is that to maximize the Manhattan distance (|x| + |y|), we want to move as far as possible in a single direction or in two perpendicular directions. For example, if we're at (x, y), we want to maximize |x| + |y|.Here's the approach:1. Track our current position (x, y) as we follow the original instructions.2. For each character, we have two options:* Keep it as is* Change it to one of the other directions (if we have changes left)3. To maximize distance, we should change characters that move us closer to the origin to characters that move us further away.The optimal strategy is to change characters that move us toward the origin (decreasing |x| or |y|) to characters that move us away from the origin (increasing |x| or |y|). Specifically:* If x > 0, change 'W' to 'E'* If x < 0, change 'E' to 'W'* If y > 0, change 'S' to 'N'* If y < 0, change 'N' to 'S'We'll simulate the movement and at each step calculate how much benefit we would get by changing the current character. We'll keep track of these benefits and apply the k most beneficial changes.

# %%
def maxDistance(s: str, k: int) -> int:    # Initialize position and maximum distance    x, y = 0, 0    max_distance = 0        # Track the original path    original_path = []    for char in s:        if char == 'N':            y += 1        elif char == 'S':            y -= 1        elif char == 'E':            x += 1        elif char == 'W':            x -= 1                original_path.append((x, y))        max_distance = max(max_distance, abs(x) + abs(y))        # Calculate potential benefits of changing each character    benefits = []    x, y = 0, 0        for i, char in enumerate(s):        old_x, old_y = x, y                # Move according to the original instruction        if char == 'N':            y += 1        elif char == 'S':            y -= 1        elif char == 'E':            x += 1        elif char == 'W':            x -= 1                # Calculate the benefit of changing this character        max_benefit = 0                # Try changing to 'N'        if char != 'N':            benefit = 2 if char == 'S' else 1            max_benefit = max(max_benefit, benefit)                # Try changing to 'S'        if char != 'S':            benefit = 2 if char == 'N' else 1            max_benefit = max(max_benefit, benefit)                # Try changing to 'E'        if char != 'E':            benefit = 2 if char == 'W' else 1            max_benefit = max(max_benefit, benefit)                # Try changing to 'W'        if char != 'W':            benefit = 2 if char == 'E' else 1            max_benefit = max(max_benefit, benefit)                benefits.append((max_benefit, i))        # Sort benefits in descending order    benefits.sort(reverse=True)        # Apply the k most beneficial changes    changes = set()    for i in range(min(k, len(benefits))):        if benefits[i][0] > 0:  # Only apply if there's a benefit            changes.add(benefits[i][1])        # Recalculate the path with changes    x, y = 0, 0    max_distance = 0        for i, char in enumerate(s):        if i in changes:            # Apply the optimal change based on current position            if x >= 0:                x += 1  # Move East            else:                x -= 1  # Move West                        if y >= 0:                y += 1  # Move North            else:                y -= 1  # Move South        else:            # Follow original instruction            if char == 'N':                y += 1            elif char == 'S':                y -= 1            elif char == 'E':                x += 1            elif char == 'W':                x -= 1                max_distance = max(max_distance, abs(x) + abs(y))        return max_distanceWait, there's an issue with the above approach. When we change a character, we need to consider the optimal direction based on our current position at that point. Let me correct the solution:def maxDistance(s: str, k: int) -> int:    # Calculate potential benefits of changing each character    benefits = []    x, y = 0, 0        for i, char in enumerate(s):        # Calculate benefit of changing this character        benefit = 0                if char == 'N':            if y <= 0:  # If we're at or below origin, N is already optimal                benefit = 0            else:  # Otherwise, changing N to S gives 2 benefit                benefit = 2        elif char == 'S':            if y >= 0:  # If we're at or above origin, S is already optimal                benefit = 0            else:  # Otherwise, changing S to N gives 2 benefit                benefit = 2        elif char == 'E':            if x <= 0:  # If we're at or left of origin, E is already optimal                benefit = 0            else:  # Otherwise, changing E to W gives 2 benefit                benefit = 2        elif char == 'W':            if x >= 0:  # If we're at or right of origin, W is already optimal                benefit = 0            else:  # Otherwise, changing W to E gives 2 benefit                benefit = 2                benefits.append((benefit, i))                # Update position        if char == 'N':            y += 1        elif char == 'S':            y -= 1        elif char == 'E':            x += 1        elif char == 'W':            x -= 1        # Sort benefits in descending order    benefits.sort(reverse=True)        # Apply the k most beneficial changes    changes = set()    for i in range(min(k, len(benefits))):        if benefits[i][0] > 0:  # Only apply if there's a benefit            changes.add(benefits[i][1])        # Recalculate the path with changes    x, y = 0, 0    max_distance = 0        for i, char in enumerate(s):        if i in changes:            # Apply the optimal change based on current position            if char == 'N':                y -= 1  # Change N to S            elif char == 'S':                y += 1  # Change S to N            elif char == 'E':                x -= 1  # Change E to W            elif char == 'W':                x += 1  # Change W to E        else:            # Follow original instruction            if char == 'N':                y += 1            elif char == 'S':                y -= 1            elif char == 'E':                x += 1            elif char == 'W':                x -= 1                max_distance = max(max_distance, abs(x) + abs(y))        return max_distanceActually, I need to rethink this solution. The above approach doesn't correctly account for the fact that the optimal direction to change to depends on our current position at each step.Let me provide a correct solution:def maxDistance(s: str, k: int) -> int:    n = len(s)        # Function to calculate Manhattan distance    def manhattan_distance(x, y):        return abs(x) + abs(y)        # Function to simulate the path and find max distance    def simulate(changes):        x, y = 0, 0        max_dist = 0                for i, char in enumerate(s):            if i in changes:                # Choose the optimal direction based on current position                if x >= 0:                    x += 1  # Move East (maximize x)                else:                    x -= 1  # Move West (minimize x)                                if y >= 0:                    y += 1  # Move North (maximize y)                else:                    y -= 1  # Move South (minimize y)            else:                # Follow original instruction                if char == 'N':                    y += 1                elif char == 'S':                    y -= 1                elif char == 'E':                    x += 1                elif char == 'W':                    x -= 1                        max_dist = max(max_dist, manhattan_distance(x, y))                return max_dist        # Try all possible combinations of k changes    # This is too inefficient for large inputs    # We need a more efficient approach        # Let's use a greedy approach instead    # For each position, calculate how much benefit we get by changing it    benefits = []    x, y = 0, 0        for i, char in enumerate(s):        # Calculate current direction's contribution to distance        old_x, old_y = x, y        if char == 'N':            y += 1        elif char == 'S':            y -= 1        elif char == 'E':            x += 1        elif char == 'W':            x -= 1                current_dist = manhattan_distance(x, y)                # Calculate optimal direction's contribution        opt_x, opt_y = old_x, old_y        if opt_x >= 0:            opt_x += 1  # Move East        else:            opt_x -= 1  # Move West                if opt_y >= 0:            opt_y += 1  # Move North        else:            opt_y -= 1  # Move South                optimal_dist = manhattan_distance(opt_x, opt_y)                # Benefit is the difference        benefit = optimal_dist - current_dist        benefits.append((benefit, i))        # Sort benefits in descending order    benefits.sort(reverse=True)        # Select the k most beneficial changes    changes = set()    for i in range(min(k, len(benefits))):        if benefits[i][0] > 0:  # Only apply if there's a benefit            changes.add(benefits[i][1])        return simulate(changes)Wait, I'm still not accounting for the fact that changing one character affects the optimal direction for subsequent characters. Let me provide a correct solution:def maxDistance(s: str, k: int) -> int:    # Define the opposite direction    opposite = {'N': 'S', 'S': 'N', 'E': 'W', 'W': 'E'}        # Function to calculate Manhattan distance    def manhattan_distance(x, y):        return abs(x) + abs(y))        # Function to get the optimal direction based on current position    def optimal_direction(x, y):        if x >= 0:            dx = 'E'  # Move East to maximize |x|        else:            dx = 'W'  # Move West to maximize |x|                if y >= 0:            dy = 'N'  # Move North to maximize |y|        else:            dy = 'S'  # Move South to maximize |y|                return dx, dy        # Try all possible combinations of k changes    def dfs(index, x, y, changes_left, memo={}):        if index == len(s):            return manhattan_distance(x, y)                # Check if we've already computed this state        key = (index, x, y, changes_left)        if key in memo:            return memo[key]                # Follow original instruction        nx, ny = x, y        char = s[index]        if char == 'N':            ny += 1        elif char == 'S':            ny -= 1        elif char == 'E':            nx += 1        elif char == 'W':            nx -= 1                # Option 1: Don't change this character        result = max(manhattan_distance(nx, ny), dfs(index + 1, nx, ny, changes_left, memo))                # Option 2: Change this character if we have changes left        if changes_left > 0:            dx, dy = optimal_direction(x, y)                        # Try changing to optimal x-direction            if char != dx:                mx = x + (1 if dx == 'E' else -1)                result = max(result, max(manhattan_distance(mx, y),                                         dfs(index + 1, mx, y, changes_left - 1, memo)))                        # Try changing to optimal y-direction            if char != dy:                my = y + (1 if dy == 'N' else -1)                result = max(result, max(manhattan_distance(x, my),                                         dfs(index + 1, x, my, changes_left - 1, memo)))                memo[key] = result        return result        return dfs(0, 0, 0, k, {})Let me simplify and correct the solution:def maxDistance(s: str, k: int) -> int:    # Function to calculate Manhattan distance    def manhattan_distance(x, y):        return abs(x) + abs(y)        # Use dynamic programming with memoization    memo = {}        def dp(index, x, y, changes_left):        if index == len(s):            return manhattan_distance(x, y)                key = (index, x, y, changes_left)        if key in memo:            return memo[key]                # Current character        char = s[index]                # Option 1: Don't change this character        nx, ny = x, y        if char == 'N':            ny += 1        elif char == 'S':            ny -= 1        elif char == 'E':            nx += 1        elif char == 'W':            nx -= 1                result = max(manhattan_distance(nx, ny), dp(index + 1, nx, ny, changes_left))                # Option 2: Change this character if we have changes left        if changes_left > 0:            # Try all possible changes            for new_char in ['N', 'S', 'E', 'W']:                if new_char != char:                    mx, my = x, y                    if new_char == 'N':                        my += 1                    elif new_char == 'S':                        my -= 1                    elif new_char == 'E':                        mx += 1                    elif new_char == 'W':                        mx -= 1                                        result = max(result, max(manhattan_distance(mx, my),                                            dp(index + 1, mx, my, changes_left - 1)))                memo[key] = result        return result        return dp(0, 0, 0, k)

# %% [markdown]
# ## Time and Space Complexity
# * *Time Complexity**: O(n * k * 4^k)* We have n positions, and for each position, we can make up to k changes.* For each change, we have 4 possible directions to choose from.* In the worst case, we might need to explore all possible combinations of changes.* The memoization helps reduce this significantly, but in

# %% [markdown]
# ## Test Cases

# %%
def maxDistance(s: str, k: int) -> int:    # Calculate potential benefits of changing each character    benefits = []    x, y = 0, 0        for i, char in enumerate(s):        # Calculate benefit of changing this character        benefit = 0                if char == 'N':            if y <= 0:  # If we're at or below origin, N is already optimal                benefit = 0            else:  # Otherwise, changing N to S gives 2 benefit                benefit = 2        elif char == 'S':            if y >= 0:  # If we're at or above origin, S is already optimal                benefit = 0            else:  # Otherwise, changing S to N gives 2 benefit                benefit = 2        elif char == 'E':            if x <= 0:  # If we're at or left of origin, E is already optimal                benefit = 0            else:  # Otherwise, changing E to W gives 2 benefit                benefit = 2        elif char == 'W':            if x >= 0:  # If we're at or right of origin, W is already optimal                benefit = 0            else:  # Otherwise, changing W to E gives 2 benefit                benefit = 2                benefits.append((benefit, i))                # Update position        if char == 'N':            y += 1        elif char == 'S':            y -= 1        elif char == 'E':            x += 1        elif char == 'W':            x -= 1        # Sort benefits in descending order    benefits.sort(reverse=True)        # Apply the k most beneficial changes    changes = set()    for i in range(min(k, len(benefits))):        if benefits[i][0] > 0:  # Only apply if there's a benefit            changes.add(benefits[i][1])        # Recalculate the path with changes    x, y = 0, 0    max_distance = 0        for i, char in enumerate(s):        if i in changes:            # Apply the optimal change based on current position            if char == 'N':                y -= 1  # Change N to S            elif char == 'S':                y += 1  # Change S to N            elif char == 'E':                x -= 1  # Change E to W            elif char == 'W':                x += 1  # Change W to E        else:            # Follow original instruction            if char == 'N':                y += 1            elif char == 'S':                y -= 1            elif char == 'E':                x += 1            elif char == 'W':                x -= 1                max_distance = max(max_distance, abs(x) + abs(y))        return max_distance
